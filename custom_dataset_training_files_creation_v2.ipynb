# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

# %%
# !nvidia-smi
# Out:
# Wed Apr 19 10:54:32 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ln  -s  '/content/drive/My drive/' /currdrive

# %%
#shutil.move("/currdrive/yolov4/Dataset_and_Annotations/Dataset/train/Computer monitor_Mobile phone", "/currdrive/yolov4/darknet/data")
# no spaCE is required in the folder name so it was giving the error so i directly move the folder into darknet data folder

# %%
image_path = '/content/drive/My Drive/yolov4/darknet/data/data_new'
os.chdir(image_path)

# %%
path_list = []

for current_dir, dirs, files in os.walk('.'):

    for f in files:
      if f.endswith('.jpg'):
        file_loc = image_path + '/' + f
        path_list.append(file_loc + '\n')

# %%
print(path_list)
print(len(path_list))
# Out:
# ['/content/drive/My Drive/yolov4/darknet/data/data_new/frame296.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame302.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame294.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame303.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame300.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame298.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame305.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame299.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame297.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame306.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame295.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame304.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame301.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/data_new/frame341.jpg\n', '/c
# ...

# %%
path_list_test = path_list[:int(len(path_list) * 0.20)]
path_list = path_list[int(len(path_list) * 0.20):]

# %%
with open('train_v3.txt', 'w') as train:
  for i in path_list:
    train.write(i)

with open('test_v3.txt', 'w') as test:
  for i in path_list_test:
    test.write(i)

# %%
# creating classes.names file
i = 0
with open(image_path + '/' + 'classes_v3.names', 'w') as cls, \
     open(image_path + '/' 'classes.txt', 'r') as text:

    for l in text:
      cls.write(l)

      i+=1

# %%
# create .data file
with open(image_path + '/' + 'image_data_v3.data', 'w') as data:
   # write total number of classes
  data.write('classes = ' + str(i) + '\n')

  # write path of train file
  data.write('train = ' + image_path + '/' + 'train_v3.txt' + '\n')

  # write fully qualified path of the test.txt
  data.write('valid = ' + image_path + '/' + 'test_v3.txt' + '\n')

  # write fully qualified path of the classes.names file
  data.write('names = ' + image_path + '/' + 'classes_v3.names' + '\n')

  # specifiy the path to save trained model weights
  data.write('backup = backup_v3')
