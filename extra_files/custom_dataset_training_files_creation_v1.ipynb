# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

# %%
# !ln  -s  '/content/drive/My drive/' /currdrive
# Out:
# ln: failed to create symbolic link '/currdrive': File exists

# %%
#shutil.move("/currdrive/yolov4/Dataset_and_Annotations/Dataset/train/Computer monitor_Mobile phone", "/currdrive/yolov4/darknet/data")
# no spaCE is required in the folder name so it was giving the error so i directly move the folder into darknet data folder

# %%
image_path = '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone'
os.chdir(image_path)

# %%
path_list = []

for current_dir, dirs, files in os.walk('.'):

    for f in files:
      if f.endswith('.jpg'):
        file_loc = image_path + '/' + f
        path_list.append(file_loc + '\n')

# %%
print(path_list)
# Out:
# ['/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/b8f416b2f75c5d70.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/b917e074f334d668.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/b920cadc5e7414bf.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/b9278b3062091d08.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/b940e50839523819.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/b9514ced7e463c9f.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/b9e69a7c91c1675a.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/ba47859e5bcbd766.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/ba4e62c7bc6e1c3c.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/ba57e00ec9fc61d4.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/ba8a026c1903fbd6.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/ba9cc8c898a3a5c9.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bac20b79e0e6cab1.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bac165fb574cca03.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bb435357ec72f6ca.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bb79299f7b7cba93.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bb7e6a863a6e9c0b.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bb8c6d3b6554a095.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bba2191640c69fb5.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bbb48e30f1349877.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bbca7eb4b7fb5f5d.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bbca9996ef3adb1c.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bbcd837c16d8e795.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bbda54af831c8dd2.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bc23de84c2aa4646.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bc8a3fe06e3b180e.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bcd283d98c65f33b.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bce00b77ee6f9d56.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bce41081de99576c.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bd0dc7baf48c5d8a.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bda18a77653b867e.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bda92ece8a89af09.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bdb60cb88fd0f3a9.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bdcab66bf61c6727.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bdff7e84fbf5837c.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/be3379949d1cba58.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/be3ccb55d9fd49bd.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/be66bd7578918726.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/be8bb6f7ccfba767.jpg\n', '/content/drive/My Drive/yolov4/darknet/data/Computer_monitor_Mobile_phone/bf218ad6c0fcdf8a.jpg\n', ...

# %%
path_list_test = path_list[:int(len(path_list) * 0.20)]
path_list = path_list[int(len(path_list) * 0.20):]

# %%
with open('train.txt', 'w') as train:
  for i in path_list:
    train.write(i)

with open('test.txt', 'w') as test:
  for i in path_list_test:
    test.write(i)

# %%
# creating classes.names file
i = 0
with open(image_path + '/' + 'classes.names', 'w') as cls, \
     open(image_path + '/' 'classes.txt', 'r') as text:

    for l in text:
      cls.write(l)

      i+=1

# %%
# create .data file
with open(image_path + '/' + 'image_data.data', 'w') as data:
   # write total number of classes
  data.write('classes = ' + str(i) + '\n')

  # write path of train file
  data.write('train = ' + image_path + '/' + 'train.txt' + '\n')

  # write fully qualified path of the test.txt
  data.write('valid = ' + image_path + '/' + 'test.txt' + '\n')

  # write fully qualified path of the classes.names file
  data.write('names = ' + image_path + '/' + 'classes.names' + '\n')

  # specifiy the path to save trained model weights
  data.write('backup = backup')
